# %% [markdown]
# スクリプト実行に必要な環境をセットアップします。

# %%
# %run startup.py
load_questions()

# %%
import os
#from pybatfish.client.commands import *
#from pybatfish.question.question import load_questions, list_questions
#from pybatfish.question import bfq

'''
出力結果の見方:
Line_Contentはどのアクセスリストがその通信を許可しているのか表示
'''
acl_file = 'networks/example-filters/mycandidate/config/ASA_acl.cfg'
def acl_test(config):
    src = []
    ip_flow = HeaderConstraints(srcIps='10.1.0.1',
                             dstIps='255.255.255.0')
    answer = bfq.testFilters(headers=ip_flow,
                             nodes='before_summary_asa',
                             filters="SPLIT-ACL").answer() 
    show(answer.frame())

def main():
  os.system('python startup.py')
  
  # Initialize a network and a snapshot
  bf_set_network("network-example-filters")
  
  SNAPSHOT_NAME = "mycurrent"
  SNAPSHOT_PATH = "networks/example-filters/mycurrent"
  bf_init_snapshot(SNAPSHOT_PATH, name=SNAPSHOT_NAME, overwrite=True)
  load_questions()
  
  parse_warning = bfq.parseWarning().answer().frame()
  print(parse_warning)
  
  parse_status = bfq.fileParseStatus().answer().frame()
  print('--------')
  print(parse_status)

if __name__ == '__main__':
    main()
# Out:
# Your snapshot was successfully initialized but Batfish failed to fully recognized some lines in one or more input files. Some unrecognized configuration lines are not uncommon for new networks, and it is often fine to proceed with further analysis. You can help the Batfish developers improve support for your network by running:
#
#     bf_upload_diagnostics(dry_run=False, contact_info='<optional email address>')
#
# to share private, anonymized information. For more information, see the documentation with:
#
#     help(bf_upload_diagnostics)
#                           Filename  \
# 0   configs/after_summary_asa.cfg
# 1   configs/after_summary_asa.cfg
# 2   configs/after_summary_asa.cfg
# 3   configs/after_summary_asa.cfg
# 4   configs/after_summary_asa.cfg
# 5   configs/after_summary_asa.cfg
# 6   configs/after_summary_asa.cfg
# 7   configs/before_summary_asa.cfg
# 8   configs/before_summary_asa.cfg
# 9   configs/before_summary_asa.cfg
# 10  configs/before_summary_asa.cfg
# 11  configs/before_summary_asa.cfg
# 12  configs/before_summary_asa.cfg
# 13  configs/ciscoasa.cfg
# 14  configs/ciscoasa.cfg
# 15  configs/ciscoasa.cfg
# 16  configs/ciscoasa.cfg
# 17  configs/ciscoasa.cfg
# 18  configs/ciscoasa.cfg
#
#                                                               Text  Line  \
# 0   absolute start 00:00 01 January 2019 end 00:00 01 January 2020  81
# 1   absolute start 00:00 01 January 2019 end 00:00 01 January 2020  84
# 2   service-object icmp echo 1                                      607
# 3   service-object icmp echo 1                                      610
# 4   service-object icmp echo 1                                      678
# 5   access-list standard permit 10.20.0.0 255.255.254.0             1086
# 6   aaa authentication login-history                                1131
# 7   absolute start 00:00 01 January 2019 end 00:00 01 January 2020  81
# 8   absolute start 00:00 01 January 2019 end 00:00 01 January 2020  84
# 9   service-object icmp echo 1                                      607
# 10  service-object icmp echo 1                                      610
# 11  service-object icmp echo 1                                      678
# 12  aaa authentication login-history                                1135
# 13  absolute start 00:00 01 January 2019 end 00:00 01 January 2020  81
# 14  absolute start 00:00 01 January 2019 end 00:00 01 January 2020  84
# 15  service-object icmp echo 1                                      607
# 16  service-object icmp echo 1                                      610
# 17  service-object icmp echo 1                                      678
# 18  aaa authentication login-history                                1161
#
#                                                                Parser_Context  \
# 0   [cisco_configuration]
# 1   [cisco_configuration]
# 2   [ogs_service_object og_service s_object_group stanza cisco_configuration]
# 3   [ogs_service_object og_service s_object_group stanza cisco_configuration]
# 4   [ogs_service_object og_service s_object_group stanza cisco_configuration]
# 5   [stanza cisco_configuration]
# 6   [aaa_authentication s_aaa stanza cisco_configuration]
# 7   [cisco_configuration]
# 8   [cisco_configuration]
# 9   [ogs_service_object og_service s_object_group stanza cisco_configuration]
# 10  [ogs_service_object og_service s_object_group stanza cisco_configuration]
# 11  [ogs_service_object og_service s_object_group stanza cisco_configuration]
# 12  [aaa_authentication s_aaa stanza cisco_configuration]
# 13  [cisco_configuration]
# 14  [cisco_configuration]
# 15  [ogs_service_object og_service s_object_group stanza cisco_configuration]
# 16  [ogs_service_object og_service s_object_group stanza cisco_configuration]
# 17  [ogs_service_object og_service s_object_group stanza cisco_configuration]
# 18  [aaa_authentication s_aaa stanza cisco_configuration]
#
#                         Comment
# 0   This syntax is unrecognized
# 1   This syntax is unrecognized
# 2   This syntax is unrecognized
# 3   This syntax is unrecognized
# 4   This syntax is unrecognized
# 5   This syntax is unrecognized
# 6   This syntax is unrecognized
# 7   This syntax is unrecognized
# 8   This syntax is unrecognized
# 9   This syntax is unrecognized
# 10  This syntax is unrecognized
# 11  This syntax is unrecognized
# 12  This syntax is unrecognized
# 13  This syntax is unrecognized
# 14  This syntax is unrecognized
# 15  This syntax is unrecognized
# 16  This syntax is unrecognized
# 17  This syntax is unrecognized
# 18  This syntax is unrecognized
# --------
#                         File_Name                  Status  \
# 0  configs/N9k-v1.cfg              PASSED
# 1  configs/after_summary_asa.cfg   PARTIALLY_UNRECOGNIZED
# 2  configs/before_summary_asa.cfg  PARTIALLY_UNRECOGNIZED
# 3  configs/ciscoasa.cfg            PARTIALLY_UNRECOGNIZED
#
#                     Nodes
# 0  ['n9kv-1']
# 1  ['after_summary_asa']
# 2  ['before_summary_asa']
# 3  ['ciscoasa']
